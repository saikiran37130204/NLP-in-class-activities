# %% [markdown]
# <a href="https://colab.research.google.com/github/saikiran37130204/NLP-in-class-activities/blob/main/Demo_Activity_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Instructions:
# ##1.This assignment is for practice purposes and won't be graded or scored.
# ##2.This assignment is specially for newcomers.

# %% [markdown]
# ##Exercise -1
# Here is example for print function,Now using the print() funtion create variable and print your name and age

# %%
##example
print("hello world")
# Out:
# hello world

# %% [markdown]
# ##Tokenization
#
# Tokenization is the process of splitting text into smaller units called tokens. It is a fundamental step in natural language processing (NLP) tasks. Tokenization breaks down sentences and paragraphs into individual words, punctuation, and numbers - capturing the basic linguistic units for analysis. Effective tokenization is key for feeding text data into machine learning models and deriving insights.

# %%
# !pip install nltk
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# !conda install nltk
# Out:
# /bin/bash: line 1: conda: command not found

# %%
text = "Natural language processing (NLP) is a subfield of linguistics, computer science, and artificial intelligence concerned with the interactions between computers and human language, in particular how to program computers to process and analyze large amounts of natural language data."

# Tokenize the text
tokens = nltk.word_tokenize(text)

print("tokens:",tokens)
# Out:
# tokens: ['Natural', 'language', 'processing', '(', 'NLP', ')', 'is', 'a', 'subfield', 'of', 'linguistics', ',', 'computer', 'science', ',', 'and', 'artificial', 'intelligence', 'concerned', 'with', 'the', 'interactions', 'between', 'computers', 'and', 'human', 'language', ',', 'in', 'particular', 'how', 'to', 'program', 'computers', 'to', 'process', 'and', 'analyze', 'large', 'amounts', 'of', 'natural', 'language', 'data', '.']

# %% [markdown]
# ##Exercise -2
# ##Using the above methods implement tokenization on your own corpus

# %%
##your code here
text = "NLP stands for Natural Language Processing, a machine learning technology that allows computers to understand, interpret, and manipulate human language. It's a branch of artificial intelligence (AI) that draws from computer science, linguistics, and computational linguistics. NLP uses statistical methods, neural networks, machine learning, and text mining to help computers process and understand human language"

# Tokenize the text
tokens = nltk.word_tokenize(text)

print("tokens:",tokens)
# Out:
# tokens: ['NLP', 'stands', 'for', 'Natural', 'Language', 'Processing', ',', 'a', 'machine', 'learning', 'technology', 'that', 'allows', 'computers', 'to', 'understand', ',', 'interpret', ',', 'and', 'manipulate', 'human', 'language', '.', 'It', "'s", 'a', 'branch', 'of', 'artificial', 'intelligence', '(', 'AI', ')', 'that', 'draws', 'from', 'computer', 'science', ',', 'linguistics', ',', 'and', 'computational', 'linguistics', '.', 'NLP', 'uses', 'statistical', 'methods', ',', 'neural', 'networks', ',', 'machine', 'learning', ',', 'and', 'text', 'mining', 'to', 'help', 'computers', 'process', 'and', 'understand', 'human', 'language']

# %% [markdown]
# ##re.split()
# ##re.split() is useful for tokenizing strings in natural language processing and provides an alternative to string.split() with added regex power.

# %%
import re

text = "This is a sample sentence for regex tokenization and Natural Language Processing."

tokens = re.split("\W+", text)
print(tokens)
# Out:
# ['This', 'is', 'a', 'sample', 'sentence', 'for', 'regex', 'tokenization', 'and', 'Natural', 'Language', 'Processing', '']

# %% [markdown]
# ##Exercise -3
# ## Implement  re.split funtion to your own corpus

# %%
##your code here

import re

text = "Machine learning, a subset of artificial intelligence (AI) that allows computers to learn and improve without being explicitly programmed"

tokens = re.split("\W+", text)
print(tokens)
# Out:
# ['Machine', 'learning', 'a', 'subset', 'of', 'artificial', 'intelligence', 'AI', 'that', 'allows', 'computers', 'to', 'learn', 'and', 'improve', 'without', 'being', 'explicitly', 'programmed']

# %% [markdown]
# ##Exercise -4
# ##Using your own dataset display the head of the data and tail of the data and also plot a simple line graph
# (You can use any dataset which is available online)

# %%
##your code here

# Import necessary libraries
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load the Iris dataset from seaborn
iris = sns.load_dataset('iris')

# Display the first five rows (head) of the dataset
print("Head of the dataset:")
print(iris.head())
# Out:
# Head of the dataset:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Display the last five rows (tail) of the dataset
print("\nTail of the dataset:")
print(iris.tail())
# Out:
# Tail of the dataset:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
# Plot a simple line graph
# Here, we'll plot 'sepal_length' against the index of the dataset
plt.figure(figsize=(10, 6))
plt.plot(iris.index, iris['sepal_length'], label='Sepal Length', color='b')
plt.plot(iris.index, iris['sepal_width'], label='Sepal Width', color='g')
plt.title('Sepal Length and Width Across Different Iris Samples')
plt.xlabel('Index')
plt.ylabel('Measurement (cm)')
plt.legend()
plt.show()

# %% [markdown]
# ##References
# ##1.https://developers.google.com/edu/python/exercises/basic
# ##2.https://www.w3schools.com/python/
# ##3.https://docs.python.org/3/tutorial/
